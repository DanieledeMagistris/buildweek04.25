# %%
import os
import pandas as pd
from bs4 import BeautifulSoup

# leggi il file html salvato
with open("C:\\Users\\danie\\OneDrive\\Desktop\\sorgenti daniele\\SCARPE_SPORTIVE_MIZUNO_pag.1.html", "r", encoding="utf-8") as file:
    html = file.read()

# parsing dell'html
soup = BeautifulSoup(html, 'html.parser')

# assegnazione categoria in base al nome del file html salvato
categoria = "Scarpe Sportive Uomo Mizuno"

# inizializzazione prodotti
prodotti = []

# scraping div
div_prodotti = soup.find_all('div', class_='_0xLoFW _78xIQ- EJ4MLB f4ql6o JT3_zV')

# ciclo per estrarre i dati dei prodotti da div_prodotti
for div_prodotto in div_prodotti:
    try:
        # url prodotto
        link = div_prodotto.find('a', class_='q84f1m CKDt_l LyRfpJ JT3_zV CKDt_l _2dqvZS')
        if not link or 'href' not in link.attrs:
            continue  # salta questo prodotto se manca l'URL
        url_prodotto = link['href']
        
        # marca e nome prodotto
        marca_tag = div_prodotto.find('h3', class_='OBkCPz lystZ1 m3OCL3 HlZ_Tf ja2E95 IvrHht ZkIJC- u-kVXO')
        if not marca_tag:
            continue  # salta se manca la marca
        marca = marca_tag.text.strip().upper()

        # nome prodotto
        nome_prodotto = div_prodotto.find('h3', class_='voFjEy lystZ1 m3OCL3 HlZ_Tf ja2E95 IvrHht ZkIJC- u-kVXO').text.strip()
        
        # inizializza i prezzi
        prezzo = "N/A"
        prezzo_ordinario = "N/A"
        
        # cerca prezzo corrente (indipendentemente dal prezzo ordinario)
        # cerca prima nel formato standard
        prezzo_tag = div_prodotto.find('span', class_='voFjEy lystZ1 Sb5G3D HlZ_Tf')
        if not prezzo_tag:
            # cerca su altri formati di prezzo
            prezzo_tag = div_prodotto.find('span', class_='voFjEy lystZ1 Sb5G3D Km7l2y')
        if not prezzo_tag:
            prezzo_tag = div_prodotto.find('span', class_='voFjEy lystZ1 m3OCL3 HlZ_Tf')
        
        if prezzo_tag:
            prezzo = prezzo_tag.text.strip().replace('€', '').strip()
        
        # cerca prezzo ordinario (solo se esiste)
        # cerca la sezione che contiene "prezzo ordinario"
        for p_tag in div_prodotto.find_all('p', class_='voFjEy _2kjxJ6 m3OCL3 HlZ_Tf _0xLoFW u9KIT8 _7ckuOK vSgP6A'):
            if 'Prezzo ordinario:' in p_tag.text:
                # prendi il primo span con il prezzo dopo il testo "prezzo ordinario"
                for span in p_tag.find_all('span', class_='voFjEy goVnUa m3OCL3 Yb63TQ'):
                    if 'Prezzo ordinario:' not in span.text:
                        prezzo_ordinario = span.text.strip().replace('€', '').strip()
                        break
                # se non trovato, prova con la classe alternativa
                if prezzo_ordinario == "N/A":
                    for span in p_tag.find_all('span', class_='voFjEy goVnUa m3OCL3 Yb63TQ ZiDB59 uVxVjw'):
                        prezzo_ordinario = span.text.strip().replace('€', '').strip()
                        break

        if prezzo_ordinario == "N/A":
            prezzo_ordinario = prezzo
        
        # se la marca è fra le 4 note, aggiungi i dati alla lista/dizionario
        if marca in ['MIZUNO']:
            prodotti.append({
                "categoria": categoria,
                "marca": marca.upper(),
                "nome_prodotto": nome_prodotto,
                "prezzo_effettivo": prezzo,
                "prezzo_ordinario": prezzo_ordinario, 
                "url_prodotto": url_prodotto,
            })
            
    except Exception as e:
        print(f"Errore durante l'elaborazione: {str(e)}")
        continue

# crea dataframe
df_completo = pd.DataFrame(prodotti)

# visualizza dataframe
display(df_completo)
#salvo in un csv
df_completo.to_csv("prodotti_gruppo3-1.csv", index=False)
# Out:
#                       categoria   marca  \
# 0   Scarpe Sportive Uomo Mizuno  MIZUNO
# 1   Scarpe Sportive Uomo Mizuno  MIZUNO
# 2   Scarpe Sportive Uomo Mizuno  MIZUNO
# 3   Scarpe Sportive Uomo Mizuno  MIZUNO
# 4   Scarpe Sportive Uomo Mizuno  MIZUNO
# ..                          ...     ...
# 78  Scarpe Sportive Uomo Mizuno  MIZUNO
# 79  Scarpe Sportive Uomo Mizuno  MIZUNO
# 80  Scarpe Sportive Uomo Mizuno  MIZUNO
# 81  Scarpe Sportive Uomo Mizuno  MIZUNO
# 82  Scarpe Sportive Uomo Mizuno  MIZUNO
#
#                                         nome_prodotto prezzo_effettivo  \
# 0          NEO ZEN - Scarpe da corsa su strada - mint           149,99
# 1   WAVE SKY 8 - Scarpe da corsa su strada - blue ...           189,99
# 2   WAVE DIMENSION - Scarpe da pallavolo - black/n...            89,99
# 3   THUNDER BLADE Z MID - Scarpe da pallavolo - wh...            75,99
# 4   WAVE DRIVE NEO 3 - Scarpe da pallavolo - white...           119,99
# ..                                                ...              ...
# 78  MONARCIDA NEO III  - Scarpe da calcetto con ta...            69,99
# 79  BREAK SHOT 5 CC - da tennis per terra battuta ...            71,99
# 80  MONARCIDA NEO SELECT - Scarpe da calcetto con ...            44,99
# 81  THUNDER BLADE Z - Scarpe da pallavolo - white/...            71,99
# 82  WAVE SKYRISE 6 - Scarpe da corsa su strada - d...           149,99
#
#    prezzo_ordinario                                       url_prodotto
# 0            149,99  https://www.zalando.it/mizuno-neo-zen-scarpe-d...
# 1            189,99  https://www.zalando.it/mizuno-wave-sky-8-scarp...
# 2             99,99  https://www.zalando.it/mizuno-wave-dimension-s...
# 3             89,99  https://www.zalando.it/mizuno-thunder-blade-z-...
# 4            149,99  https://www.zalando.it/mizuno-wave-drive-neo-3...
# ..              ...                                                ...
# 78            69,99  https://www.zalando.it/mizuno-monarcida-neo-ii...
# 79            79,99  https://www.zalando.it/mizuno-break-shot-5-cla...
# 80            69,99  https://www.zalando.it/mizuno-monarcida-neo-ii...
# 81            79,99  https://www.zalando.it/mizuno-thunder-blade-z-...
# 82           149,99  https://www.zalando.it/mizuno-wave-skyrise-6-s...
#
# [83 rows x 6 columns]

# %%
import os
import pandas as pd
from bs4 import BeautifulSoup

# leggi il file html salvato
with open("C:\\Users\\danie\\OneDrive\\Desktop\\sorgenti daniele\\SCARPE_SPORTIVE_MIZUNO_pag2.html", "r", encoding="utf-8") as file:
    html = file.read()

# parsing dell'html
soup = BeautifulSoup(html, 'html.parser')

# assegnazione categoria in base al nome del file html salvato
categoria = "Scarpini Mizuno Uomo"

# inizializzazione prodotti
prodotti = []

# scraping div
div_prodotti = soup.find_all('div', class_='_0xLoFW _78xIQ- EJ4MLB f4ql6o JT3_zV')

# ciclo per estrarre i dati dei prodotti da div_prodotti
for div_prodotto in div_prodotti:
    try:
        # url prodotto
        link = div_prodotto.find('a', class_='q84f1m CKDt_l LyRfpJ JT3_zV CKDt_l _2dqvZS')
        if not link or 'href' not in link.attrs:
            continue  # salta questo prodotto se manca l'URL
        url_prodotto = link['href']
        
        # marca e nome prodotto
        marca_tag = div_prodotto.find('h3', class_='OBkCPz lystZ1 m3OCL3 HlZ_Tf ja2E95 IvrHht ZkIJC- u-kVXO')
        if not marca_tag:
            continue  # salta se manca la marca
        marca = marca_tag.text.strip().upper()

        # nome prodotto
        nome_prodotto = div_prodotto.find('h3', class_='voFjEy lystZ1 m3OCL3 HlZ_Tf ja2E95 IvrHht ZkIJC- u-kVXO').text.strip()
        
        # inizializza i prezzi
        prezzo = "N/A"
        prezzo_ordinario = "N/A"
        
        # cerca prezzo corrente (indipendentemente dal prezzo ordinario)
        # cerca prima nel formato standard
        prezzo_tag = div_prodotto.find('span', class_='voFjEy lystZ1 Sb5G3D HlZ_Tf')
        if not prezzo_tag:
            # cerca su altri formati di prezzo
            prezzo_tag = div_prodotto.find('span', class_='voFjEy lystZ1 Sb5G3D Km7l2y')
        if not prezzo_tag:
            prezzo_tag = div_prodotto.find('span', class_='voFjEy lystZ1 m3OCL3 HlZ_Tf')
        
        if prezzo_tag:
            prezzo = prezzo_tag.text.strip().replace('€', '').strip()
        
        # cerca prezzo ordinario (solo se esiste)
        # cerca la sezione che contiene "prezzo ordinario"
        for p_tag in div_prodotto.find_all('p', class_='voFjEy _2kjxJ6 m3OCL3 HlZ_Tf _0xLoFW u9KIT8 _7ckuOK vSgP6A'):
            if 'Prezzo ordinario:' in p_tag.text:
                # prendi il primo span con il prezzo dopo il testo "prezzo ordinario"
                for span in p_tag.find_all('span', class_='voFjEy goVnUa m3OCL3 Yb63TQ'):
                    if 'Prezzo ordinario:' not in span.text:
                        prezzo_ordinario = span.text.strip().replace('€', '').strip()
                        break
                # se non trovato, prova con la classe alternativa
                if prezzo_ordinario == "N/A":
                    for span in p_tag.find_all('span', class_='voFjEy goVnUa m3OCL3 Yb63TQ ZiDB59 uVxVjw'):
                        prezzo_ordinario = span.text.strip().replace('€', '').strip()
                        break

        if prezzo_ordinario == "N/A":
            prezzo_ordinario = prezzo
        
        # se la marca è fra le 4 note, aggiungi i dati alla lista/dizionario
        if marca in ['MIZUNO']:
            prodotti.append({
                "categoria": categoria,
                "marca": marca.upper(),
                "nome_prodotto": nome_prodotto,
                "prezzo_effettivo": prezzo,
                "prezzo_ordinario": prezzo_ordinario, 
                "url_prodotto": url_prodotto,
            })
            
    except Exception as e:
        print(f"Errore durante l'elaborazione: {str(e)}")
        continue

# crea dataframe
df_temp = pd.DataFrame(prodotti)

display(df_temp)

#salvo in un csv
df_temp.to_csv("prodotti_gruppo3-2.csv", index=False)
# Out:
#                categoria   marca  \
# 0   Scarpini Mizuno Uomo  MIZUNO
# 1   Scarpini Mizuno Uomo  MIZUNO
# 26           170,00  https://www.zalando.it/mizuno-wave-stealth-neo...
# 27           150,00  https://www.zalando.it/mizuno-wave-exceed-tour...
# 28           125,00  https://www.zalando.it/mizuno-sneakers-basse-m...
# 29           160,00  https://www.zalando.it/mizuno-da-tennis-per-te...
# 30           117,00  https://www.zalando.it/mizuno-morelia-neo-iv-p...
# 31           119,99  https://www.zalando.it/mizuno-morelia-ii-pro-r...
# 32           160,00  https://www.zalando.it/mizuno-morelia-ii-elite...
# 33           150,00  https://www.zalando.it/mizuno-wave-daichi-8-sc...
# 34            69,99  https://www.zalando.it/mizuno-sala-club-in-sca...

# %%
file_list = ['prodotti_gruppo3-1.csv', 'prodotti_gruppo3-2.csv']

df_completo = pd.concat([pd.read_csv(file, encoding='utf-8') for file in file_list], ignore_index=True)

df_completo.to_csv('prodotti mizuno Unito.csv', index=False)

df_completo
# Out:
#                        categoria   marca  \
# 0    Scarpe Sportive Uomo Mizuno  MIZUNO
# 1    Scarpe Sportive Uomo Mizuno  MIZUNO
# 2    Scarpe Sportive Uomo Mizuno  MIZUNO
# 3    Scarpe Sportive Uomo Mizuno  MIZUNO
# 4    Scarpe Sportive Uomo Mizuno  MIZUNO
# ..                           ...     ...
# 113         Scarpini Mizuno Uomo  MIZUNO
# 114         Scarpini Mizuno Uomo  MIZUNO
# 115         Scarpini Mizuno Uomo  MIZUNO
# 116         Scarpini Mizuno Uomo  MIZUNO
# 117         Scarpini Mizuno Uomo  MIZUNO
#
#                                          nome_prodotto prezzo_effettivo  \
# 0           NEO ZEN - Scarpe da corsa su strada - mint           149,99
# 1    WAVE SKY 8 - Scarpe da corsa su strada - blue ...           189,99
# 2    WAVE DIMENSION - Scarpe da pallavolo - black/n...            89,99
# 3    THUNDER BLADE Z MID - Scarpe da pallavolo - wh...            75,99
# 4    WAVE DRIVE NEO 3 - Scarpe da pallavolo - white...           119,99
# ..                                                 ...              ...
# 113  MORELIA NEO IV PRO - Scarpe da calcetto con ta...           117,00
# 114  MORELIA II PRO RUN ON - Scarpe da calcetto con...           101,99
# 115  MORELIA II ELITE - Scarpe da calcetto con tacc...           128,00
# 116  WAVE DAICHI 8 - Scarpe da trail running - esta...           121,73
# 117  SALA CLUB IN - Scarpe da calcetto - mugen blue...            41,99
#
#     prezzo_ordinario                                       url_prodotto
# 0             149,99  https://www.zalando.it/mizuno-neo-zen-scarpe-d...
# 1             189,99  https://www.zalando.it/mizuno-wave-sky-8-scarp...
# 2              99,99  https://www.zalando.it/mizuno-wave-dimension-s...
# 3              89,99  https://www.zalando.it/mizuno-thunder-blade-z-...
# 4             149,99  https://www.zalando.it/mizuno-wave-drive-neo-3...
# ..               ...                                                ...
# 113           117,00  https://www.zalando.it/mizuno-morelia-neo-iv-p...
# 114           119,99  https://www.zalando.it/mizuno-morelia-ii-pro-r...
# 115           160,00  https://www.zalando.it/mizuno-morelia-ii-elite...
# 116           150,00  https://www.zalando.it/mizuno-wave-daichi-8-sc...
# 117            69,99  https://www.zalando.it/mizuno-sala-club-in-sca...
#
# [118 rows x 6 columns]
